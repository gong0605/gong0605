# %% [markdown]
# <a href="https://colab.research.google.com/github/gong0605/gong0605/blob/main/Chapter_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1번
#import turtle
#t = turtle.Turtle()
#t.shape("turtle")
#t.color("black", "white")
#s = turtle.Screen(); s.bgcolor('skyblue');
#def draw_snowman(x, y):
  #t.up()
  #t.goto(x, y)
  #t.down()
  #t.circle(20)
  #t.end_fill()
  #t.goto(x, y-25)
  #t.setheading(135)
  #t.forward(50)
  #t.backward(50)
  #t.setheading(30)
  #t.forward(50)
  #t.backward(50)
  #t.setheading(0)
  #t.begin_fill()
  #t.circle(15)
  #t.end_fill()
  #t.goto(x, y-70)
  #t.begin_fill()
  #t.circle(30)
  #t.end_fill()
#draw_snowman(0, 0)
#draw_snowman(100, 0)
#draw_snowman(200, 0)
print("#"*5)
#2번
#import turtle 
#t = turtle.Turtle()
#t.shape("turtle")
#t.speed(0)
#def hexagon():
  #for i in range(6):
    #turtle.forward(100)
    #turtle.left(360/6)
#for i in range (6):
  #hexagon()
  #turtle.forward(100)
  #turtle.right(60)
print("#"*5)
#3번
#import turtle 
#t = turtle.Turtle()
#t.shape("turtle")
#t.speed(0)
#def f(x):
#  return x**2+1
#t.goto(200, 0)
#t.goto(0, 0)
#t.goto(0, 200)
#t.goto(0, 0)
#for x in range(150):
  #t.goto(x, int(0.01*f(x)))
print("#"*5)
#4번
#import turtle 
#t = turtle.Turtle()
#t.shape("turtle")
#t.speed(0)
#def draw_line():
  #t.forward(100)
  #t.backward(100)
#for x in range(12):
  #t.right(30)
  #draw_line()
print("#"*5)
#5번
def happyBirthday(person):
  print("Happy Birthday to you!")
  print("Happy Birthday to you!")
  print("Happy Birthday, dear " + person)
  print("Happy Birthday to you!")
happyBirthday("홍길동")
print("#"*5)
#6번
def sumProblem(x, y):
  sum = x + y
  sentence = "정수" + str(x) + "+"+str(y)+"의 합은?"
  print(sentence)
def main():
  a = int(input("첫 번째 정수: "))
  b = int(input("두 번째 정수: "))
  sumProblem(a, b)
main()
print("#"*5)
#7번
PI = 3.14159265358979 
def circleArea(radius):
  return PI*radius*radius 
def circleCircumference(radius):
  return 2*PI*radius 
def main():
  print('반지름이 5인 원의 면적:', circleArea(5))
  print('반지름이 5인 원의 둘레:', circleCircumference(5))
main()
print("#"*5)
#8번
def add(a, b):
  print( "(%d + %d)" % (a, b), end=" ")
  return a + b
def subtract(a, b):
  print ("(%d - %d)" % (a, b), end=" ")
  return a - b
def multiply(a, b):
  print ("(%d * %d)" % (a, b), end=" ")
  return a * b
def divide(a, b):
  print ("(%d / %d)" % (a, b), end=" ")
  return a / b
what = add(20, 10)
print("= ", what)
# Out:
# #####
# #####
# #####
# #####
# Happy Birthday to you!
# Happy Birthday to you!
# Happy Birthday, dear 홍길동
# Happy Birthday to you!
# #####
# 첫 번째 정수: 3
# 두 번째 정수: 3
# 정수3+3의 합은?
# #####
# 반지름이 5인 원의 면적: 78.53981633974475
# 반지름이 5인 원의 둘레: 31.4159265358979
# #####
# (20 + 10) =  30
